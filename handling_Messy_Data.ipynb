# %%
# !pip install pandas --break-system-packages
# !pip install scikit-learn --break-system-packages

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

df = pd.DataFrame({
    'customer_id': [1, 2, 3, 4, 2, 5],
    'age':         [25, np.nan, 35, np.nan, np.nan, 40],
    'city':        ['Mumbai', 'Delhi', np.nan, 'Mumbai', 'Delhi', np.nan],
    'gender':      ['Male', 'Female', 'Female', 'Male', 'Female', 'Male'],
    'annual_income': [40000, 80000, 60000, 120000, 80000, 95000]
})

# %%
df
# Out:
#    customer_id   age    city  gender  annual_income
# 0            1  25.0  Mumbai    Male          40000
# 1            2   NaN   Delhi  Female          80000
# 2            3  35.0     NaN  Female          60000
# 3            4   NaN  Mumbai    Male         120000
# 4            2   NaN   Delhi  Female          80000
# 5            5  40.0     NaN    Male          95000

# %%
df['age'] = df['age'].fillna(df['age'].median(), inplace=True)
# Out:
# /var/folders/nw/lm1tqhsj2jjcs6bl14pw4xlm0000gq/T/ipykernel_11348/3812779953.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['age'] = df['age'].fillna(df['age'].median(), inplace=True)

# %%
df
# Out:
#    customer_id   age    city  gender  annual_income
# 0            1  25.0  Mumbai    Male          40000
# 1            2  35.0   Delhi  Female          80000
# 2            3  35.0     NaN  Female          60000
# 3            4  35.0  Mumbai    Male         120000
# 4            2  35.0   Delhi  Female          80000
# 5            5  40.0     NaN    Male          95000

# %%
df['city'].mode()
# Out:
# 0     Delhi
# 1    Mumbai
# Name: city, dtype: str

# %%
df['city'] = df['city'].fillna(df['city'].mode()[0], inplace=True)
# Out:
# /var/folders/nw/lm1tqhsj2jjcs6bl14pw4xlm0000gq/T/ipykernel_11348/2316145129.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['city'] = df['city'].fillna(df['city'].mode()[0], inplace=True)

# %%
df
# Out:
#    customer_id   age    city  gender  annual_income
# 0            1  25.0  Mumbai    Male          40000
# 1            2  35.0   Delhi  Female          80000
# 2            3  35.0   Delhi  Female          60000
# 3            4  35.0  Mumbai    Male         120000
# 4            2  35.0   Delhi  Female          80000
# 5            5  40.0   Delhi    Male          95000

# %%
onehot_encoder = OneHotEncoder()

# %%
one_hot_encoded = onehot_encoder.fit_transform(df[['city']])

one_hot_encoded_df = pd.DataFrame(one_hot_encoded.toarray(), columns=onehot_encoder.get_feature_names_out(['city']))

df = pd.concat([df, one_hot_encoded_df], axis=1)
# Out:
#    customer_id   age    city  gender  annual_income  city_Delhi  city_Mumbai
# 0            1  25.0  Mumbai    Male          40000         0.0          1.0
# 1            2  35.0   Delhi  Female          80000         1.0          0.0
# 2            3  35.0   Delhi  Female          60000         1.0          0.0
# 3            4  35.0  Mumbai    Male         120000         0.0          1.0
# 4            2  35.0   Delhi  Female          80000         1.0          0.0
# 5            5  40.0   Delhi    Male          95000         1.0          0.0

# %%
label_encoder = LabelEncoder()

df['age'] = label_encoder.fit_transform(df['gender'])
# Out:
#    customer_id  age    city  gender  annual_income  city_Delhi  city_Mumbai
# 0            1    1  Mumbai    Male          40000         0.0          1.0
# 1            2    0   Delhi  Female          80000         1.0          0.0
# 2            3    0   Delhi  Female          60000         1.0          0.0
# 3            4    1  Mumbai    Male         120000         0.0          1.0
# 4            2    0   Delhi  Female          80000         1.0          0.0
# 5            5    1   Delhi    Male          95000         1.0          0.0
