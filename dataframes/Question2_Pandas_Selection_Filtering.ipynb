# %% [markdown]
# <a href="https://colab.research.google.com/github/pponali/masai/blob/main/dataframes/Question2_Pandas_Selection_Filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Create a pandas DataFrame using the employee data

# %%
import pandas as pd

# dataframe = pd.read_csv("employee.csv")
data = {
    "EmployeeID": [201, 202, 203, 204, 205, 206, 207, 208, 209, 210],
    "Name": ["Sarah", "Michael", "Jennifer", "David", "Lisa", "James", "Emma", "Robert", "Sophia", "William"],
    "Department": ["Engineering", "Sales", "Marketing", "Engineering", "HR", "Sales", "Engineering", "Marketing", "Sales", "HR"],
    "Salary": [85000, 62000, 71000, 92000, 58000, 68000, 78000, 75000, 65000, 60000],
    "Performance Score": [4, 3, 5, 5, 4, 4, 3, 4, 5, 3],
    "Years of Service": [5, 3, 7, 8, 4, 6, 2, 5, 4, 3]
}
dataframe = pd.DataFrame(data)
dataframe
# Out:
#    EmployeeID      Name   Department  Salary  Performance Score  \
# 0         201     Sarah  Engineering   85000                  4
# 1         202   Michael        Sales   62000                  3
# 2         203  Jennifer    Marketing   71000                  5
# 3         204     David  Engineering   92000                  5
# 4         205      Lisa           HR   58000                  4
# 5         206     James        Sales   68000                  4
# 6         207      Emma  Engineering   78000                  3
# 7         208    Robert    Marketing   75000                  4
# 8         209    Sophia        Sales   65000                  5
# 9         210   William           HR   60000                  3
#
#    Years of Service
# 0                 5
# 1                 3
# 2                 7
# 3                 8
# 4                 4
# 5                 6
# 6                 2
# 7                 5
# 8                 4
# 9                 3

# %% [markdown]
# # show coloumns with Name, Department and Salary.

# %%
dataframe[['Name', 'Department', 'Salary']]
# Out:
#        Name   Department  Salary
# 0     Sarah  Engineering   85000
# 1   Michael        Sales   62000
# 2  Jennifer    Marketing   71000
# 3     David  Engineering   92000
# 4      Lisa           HR   58000
# 5     James        Sales   68000
# 6      Emma  Engineering   78000
# 7    Robert    Marketing   75000
# 8    Sophia        Sales   65000
# 9   William           HR   60000

# %% [markdown]
# # Display employee details at position row 5 using iloc.

# %%
dataframe.iloc[4]
# Out:
# EmployeeID             205
# Name                  Lisa
# Department              HR
# Salary               58000
# Performance Score        4
# Years of Service         4
# Name: 4, dtype: object

# %% [markdown]
# # Display employee details at 208 location using loc.

# %%
dataframe.loc[7]
# Out:
# EmployeeID                 208
# Name                    Robert
# Department           Marketing
# Salary                   75000
# Performance Score            4
# Years of Service             5
# Name: 7, dtype: object

# %% [markdown]
# # Filter the employees based on the Engineering department.

# %%
dataframe[dataframe['Department'] == 'Engineering']
# Out:
#    EmployeeID   Name   Department  Salary  Performance Score  Years of Service
# 0         201  Sarah  Engineering   85000                  4                 5
# 3         204  David  Engineering   92000                  5                 8
# 6         207   Emma  Engineering   78000                  3                 2

# %% [markdown]
# # Filter the employees based on the salary greater than 70000.

# %%
dataframe[dataframe['Salary'] > 70000]
# Out:
#    EmployeeID      Name   Department  Salary  Performance Score  \
# 0         201     Sarah  Engineering   85000                  4
# 2         203  Jennifer    Marketing   71000                  5
# 3         204     David  Engineering   92000                  5
# 6         207      Emma  Engineering   78000                  3
# 7         208    Robert    Marketing   75000                  4
#
#    Years of Service
# 0                 5
# 2                 7
# 3                 8
# 6                 2
# 7                 5

# %% [markdown]
# # Filter the employees based on  sales department and performance rating greater than or equal to 4.

# %%
dataframe[(dataframe['Department'] == 'Sales') & (dataframe['Performance Score'] >= 4)]
# Out:
#    EmployeeID    Name Department  Salary  Performance Score  Years of Service
# 5         206   James      Sales   68000                  4                 6
# 8         209  Sophia      Sales   65000                  5                 4

# %% [markdown]
# # Sort employees based on salary in descending order and display top 3 employees.

# %%
dataframe.sort_values(['Salary'], ascending=False).head(3)
# Out:
#    EmployeeID   Name   Department  Salary  Performance Score  Years of Service
# 3         204  David  Engineering   92000                  5                 8
# 0         201  Sarah  Engineering   85000                  4                 5
# 6         207   Emma  Engineering   78000                  3                 2

# %% [markdown]
# # Sort the employees based on Department in ascending order and Salary in descending order.

# %%
dataframe.sort_values(['Department', 'Salary'], ascending=[True, False]).reset_index()
# Out:
#    index  EmployeeID      Name   Department  Salary  Performance Score  \
# 0      3         204     David  Engineering   92000                  5
# 1      0         201     Sarah  Engineering   85000                  4
# 2      6         207      Emma  Engineering   78000                  3
# 3      9         210   William           HR   60000                  3
# 4      4         205      Lisa           HR   58000                  4
# 5      7         208    Robert    Marketing   75000                  4
# 6      2         203  Jennifer    Marketing   71000                  5
# 7      5         206     James        Sales   68000                  4
# 8      8         209    Sophia        Sales   65000                  5
# 9      1         202   Michael        Sales   62000                  3
#
#    Years of Service
# 0                 8
# 1                 5
# 2                 2
# 3                 3
# 4                 4
# 5                 5
# 6                 7
# ...
